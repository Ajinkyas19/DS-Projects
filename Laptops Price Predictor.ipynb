# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Asus\Downloads\laptops.csv')

# %%
df.head(20)
# Out:
#    CompanyName        TypeOfLaptop  Inches  \
# 0          MSI     Business Laptop      17
# 1        Chuwi  2 in 1 Convertible      16
# 2           hp         WorkStation      17
# 3          MSI  2 in 1 Convertible      11
# 4    Microsoft              Gaming      12
# 5        Apple         WorkStation      15
# 6       lenevo            NoteBook      15
# 7         Asus           UltraBook      17
# 8    Microsoft     Business Laptop      12
# 9    Microsoft           UltraBook      15
# 10   Microsoft              Gaming      13
# 11         MSI  2 in 1 Convertible      11
# 12        Acer            NoteBook      15
# 13       Apple           UltraBook      12
# 14        Acer         WorkStation      16
# 15       Chuwi              Gaming      12
# 16       Apple     Business Laptop      11
# 17   Microsoft           UltraBook      13
# 18          hp         WorkStation      11
# 19       Chuwi         WorkStation      17
#
# ...

# %%
df['CompanyName'].value_counts()
# Out:
# CompanyName
# MSI          128
# Microsoft    118
# Apple        113
# lenevo       113
# Asus         112
# Chuwi        109
# Acer         107
# Dell         101
# hp            99
# Name: count, dtype: int64

# %%
df['TypeOfLaptop'].value_counts()
# Out:
# TypeOfLaptop
# Business Laptop       176
# WorkStation           175
# Gaming                168
# UltraBook             166
# 2 in 1 Convertible    162
# NoteBook              153
# Name: count, dtype: int64

# %%
df['Inches']=df['Inches'].astype('int32')

# %%
df['Weight']=df['Inches'].astype('int32')

# %%
df['Price']=df['Inches'].astype('int32')

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     270
# 12    247
# 4     243
# 16    240
# Name: count, dtype: int64

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD               322
# 2K                    181
# 4K                    179
# IPS Touchscreen HD    176
# IPS Retina QHD        142
# Name: count, dtype: int64

# %%
df['ScreenResolution'] = df['ScreenResolution'].str.replace('IPS Panel Full HD / Touchscreen 1920x1080','IPS Touchscreen HD')

# %%
df['ScreenResolution'] = df['ScreenResolution'].str.replace('IPS Panel Retina Display 2560x1600','IPS Retina QHD')

# %%
df['ScreenResolution'] = df['ScreenResolution'].str.replace('HD 1920x1080','Full HD')

# %%
df['ScreenResolution'] = df['ScreenResolution'].str.replace('Full HD ','Full HD')

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Xeon E3-1505M               114
# Intel Atom x5-Z8550               111
# Intel Core i5                     105
# Intel Pentium Quad Core N4200     101
# Intel Celeron Dual Core 3855U      98
# Intel Core i7                      96
# Intel Core i9                      95
# AMD Ryzen 5                        94
# AMD Ryzen 7                        94
# AMD A9-Series 9420                 92
# Name: count, dtype: int64

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# NVIDIA GeForce GTX 1650    348
# AMD Radeon RX 5600M        339
# Intel Iris Xe Graphics     313
# Name: count, dtype: int64

# %%
df['Memory'] = df['Memory'].str.replace('GB','')
df['Memory'] = df['Memory'].str.replace('TB','000')

# %%
df['ssd'] = df['Memory'].apply(lambda x: x.split()[0] if x.split()[-1] == 'SSD' else 0)

# %%
df['hdd'] = df['Memory'].apply(lambda x: x.split()[0] if x.split()[-1] == 'HDD' else 0)

# %%
df['Flash or eMMc'] = df['Memory'].apply(lambda x: 0 if x.split()[-1] == 'SSD' or x.split()[-1] == 'HDD' else x.split()[0])

# %%
df.head(26)
# Out:
#    CompanyName        TypeOfLaptop  Inches    ScreenResolution  \
# 0          MSI     Business Laptop      17      IPS Retina QHD
# 1        Chuwi  2 in 1 Convertible      16             Full HD
# 2           hp         WorkStation      17             Full HD
# 3          MSI  2 in 1 Convertible      11                  2K
# 4    Microsoft              Gaming      12             Full HD
# 5        Apple         WorkStation      15             Full HD
# 6       lenevo            NoteBook      15                  2K
# 7         Asus           UltraBook      17  IPS Touchscreen HD
# 8    Microsoft     Business Laptop      12      IPS Retina QHD
# 9    Microsoft           UltraBook      15             Full HD
# 10   Microsoft              Gaming      13                  2K
# 11         MSI  2 in 1 Convertible      11             Full HD
# 12        Acer            NoteBook      15             Full HD
# 13       Apple           UltraBook      12                  2K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CompanyName       1000 non-null   object
#  1   TypeOfLaptop      1000 non-null   object
#  2   Inches            1000 non-null   int32
#  3   ScreenResolution  1000 non-null   object
#  4   Cpu               1000 non-null   object
#  5   Ram               1000 non-null   object
#  6   Gpu               1000 non-null   object
#  7   OpSys             1000 non-null   object
#  8   Weight            1000 non-null   int32
#  9   Price             1000 non-null   int32
#  10  ssd               1000 non-null   object
#  11  hdd               1000 non-null   object
#  12  Flash or eMMc     1000 non-null   object
# dtypes: int32(3), object(10)
# memory usage: 90.0+ KB

# %%
df = df.drop('Memory',axis=1)

# %%
df['Ram']=df['Ram'].astype('int32')
df['ssd']=df['ssd'].astype('int32')
df['hdd']=df['hdd'].astype('int32')
df['Flash or eMMc']=df['Flash or eMMc'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CompanyName       1000 non-null   object
#  1   TypeOfLaptop      1000 non-null   object
#  2   Inches            1000 non-null   int32
#  3   ScreenResolution  1000 non-null   object
#  4   Cpu               1000 non-null   object
#  5   Ram               1000 non-null   int32
#  6   Gpu               1000 non-null   object
#  7   OpSys             1000 non-null   object
#  8   Weight            1000 non-null   int32
#  9   Price             1000 non-null   int32
#  10  ssd               1000 non-null   int32
#  11  hdd               1000 non-null   int32
#  12  Flash or eMMc     1000 non-null   int32
# dtypes: int32(7), object(6)
# memory usage: 74.3+ KB

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Xeon E3-1505M               114
# Intel Atom x5-Z8550               111
# Intel Core i5                     105
# Intel Pentium Quad Core N4200     101
# Intel Celeron Dual Core 3855U      98
# Intel Core i7                      96
# Intel Core i9                      95
# AMD Ryzen 5                        94
# AMD Ryzen 7                        94
# AMD A9-Series 9420                 92
# Name: count, dtype: int64

# %%
def cpubrand(text):
    if text == 'Intel Xeon E3-1505M ' or text == 'Intel Celeron Dual Core 3855U ' or text == 'Intel Atom x5-Z8550' or text == 'Intel Pentium Quad Core N4200':
        return 'Intel Others'
    else:
        return text

# %%
df['cpuname'] = df['Cpu'].apply(cpubrand)

# %%
cpuname.value_counts()
# Out:
# Cpu
# Intel Others          424
# Intel Core i5         105
# Intel Core i7          96
# Intel Core i9          95
# AMD Ryzen 5            94
# AMD Ryzen 7            94
# AMD A9-Series 9420     92
# Name: count, dtype: int64

# %%
df = df.drop('Cpu', axis=1)

# %%
df.head(10)
# Out:
#   CompanyName        TypeOfLaptop  Inches    ScreenResolution  Ram  \
# 0         MSI     Business Laptop      17      IPS Retina QHD   12
# 1       Chuwi  2 in 1 Convertible      16             Full HD   12
# 2          hp         WorkStation      17             Full HD    8
# 3         MSI  2 in 1 Convertible      11                  2K   16
# 4   Microsoft              Gaming      12             Full HD    8
# 5       Apple         WorkStation      15             Full HD   16
# 6      lenevo            NoteBook      15                  2K    8
# 7        Asus           UltraBook      17  IPS Touchscreen HD   12
# 8   Microsoft     Business Laptop      12      IPS Retina QHD   12
# 9   Microsoft           UltraBook      15             Full HD    8
#
#                        Gpu       OpSys  Weight  Price   ssd   hdd  \
# 0   Intel Iris Xe Graphics       Linux      17     17   512     0
# 1   Intel Iris Xe Graphics       No OS      16     16   128     0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns ='Price')
y = df['Price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
cat_columns = [0,1,3,5,6,11]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
step1 = ColumnTransformer(transformers=[
    ('col_trn',OneHotEncoder(sparse=False, drop='first'),[0,1,3,5,6,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('st1',step1),
    ('st2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)



print('R2_Score ',r2_score(y_test,y_pred))
print('Mean_absolute_Error', mean_absolute_error(y_test,y_pred))
# Out:
# R2_Score  1.0
# Mean_absolute_Error 9.237055564881303e-15

# %%
step1 = ColumnTransformer(transformers=[
    ('col_trn',OneHotEncoder(sparse=False, drop='first'),[0,1,3,5,6,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('st1',step1),
    ('st2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)



print('R2_Score ',r2_score(y_test,y_pred))
print('Mean_absolute_Error', mean_absolute_error(y_test,y_pred))
# Out:
# R2_Score  1.0
# Mean_absolute_Error 0.0

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CompanyName       1000 non-null   object
#  1   TypeOfLaptop      1000 non-null   object
#  2   Inches            1000 non-null   int32
#  3   ScreenResolution  1000 non-null   object
#  4   Ram               1000 non-null   int32
#  5   Gpu               1000 non-null   object
#  6   OpSys             1000 non-null   object
#  7   Weight            1000 non-null   int32
#  8   ssd               1000 non-null   int32
#  9   hdd               1000 non-null   int32
#  10  Flash or eMMc     1000 non-null   int32
#  11  cpuname           1000 non-null   object
# dtypes: int32(6), object(6)
# memory usage: 70.4+ KB
